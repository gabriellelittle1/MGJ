# %%
from dotenv import load_dotenv
from portia.cli import CLIExecutionHooks
from portia import *
import requests
import xml.etree.ElementTree as ET
from pydantic import BaseModel, Field
from typing import Generic, TypeVar, List

load_dotenv(override=True)
# Out:
# True

# %%
from my_custom_tools.arXivTool import ArXivTool
tool = ArXivTool()
results = tool.run(None, topic="machine learning")

for paper in results:
    print(paper["title"])
    print(paper["link"])
    print()
# Out:
# Lecture Notes: Optimization for Machine Learning
# http://arxiv.org/abs/1909.03550v1
#
# An Optimal Control View of Adversarial Machine Learning
# http://arxiv.org/abs/1811.04422v1
#
# Minimax deviation strategies for machine learning and recognition with
#   short learning samples
# http://arxiv.org/abs/1707.04849v1
#
# Machine Learning for Clinical Predictive Analytics
# http://arxiv.org/abs/1909.09246v1
#
# Towards Modular Machine Learning Solution Development: Benefits and
#   Trade-offs
# http://arxiv.org/abs/2301.09753v1

# %% [markdown]
# ## Find subtopics, gaps, open questions, etc

# %%
import urllib, urllib.request
url = 'http://export.arxiv.org/api/query?search_query=all:diffusion+models&start=0&max_results=5'
data = urllib.request.urlopen(url)
print(data.read().decode('utf-8'))
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <feed xmlns="http://www.w3.org/2005/Atom">
#   <link href="http://arxiv.org/api/query?search_query%3Dall%3Adiffusion%20models%26id_list%3D%26start%3D0%26max_results%3D5" rel="self" type="application/atom+xml"/>
#   <title type="html">ArXiv Query: search_query=all:diffusion models&amp;id_list=&amp;start=0&amp;max_results=5</title>
#   <id>http://arxiv.org/api/0OlMtxgqaDnuc6YQkFjDlR9H0uI</id>
#   <updated>2025-04-11T00:00:00-04:00</updated>
#   <opensearch:totalResults xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">1025432</opensearch:totalResults>
#   <opensearch:startIndex xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">0</opensearch:startIndex>
#   <opensearch:itemsPerPage xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">5</opensearch:itemsPerPage>
#   <entry>
#     <id>http://arxiv.org/abs/1701.00257v2</id>
#     <updated>2017-01-05T17:58:43Z</updated>
#     <published>2017-01-01T16:01:13Z</published>
# ...
